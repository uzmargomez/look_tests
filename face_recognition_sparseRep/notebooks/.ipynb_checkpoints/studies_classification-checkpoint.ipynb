# %%
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix, 
    classification_report,
    ConfusionMatrixDisplay,
    roc_curve,
    RocCurveDisplay,
)


plt.rcParams['figure.figsize'] = [15, 15]
plt.rcParams.update({'font.size': 16})

accuracy = []

sizes = [8,16,24,32,40,48]

for size in sizes:
    file = open(f'data/output{size}.txt', 'r')
    lines = file.readlines()
    
    y_true = []
    y_pred = []    
    
    for l in lines:
        l = l.replace(" ","").replace("*NOTINDB*","Unknown")
        result = l.split("|")
        
        y_true.append(result[0])
        y_pred.append(result[1])
    
    names = list(set(y_true))
    cm = confusion_matrix(y_true, y_pred,labels=names)
    
    disp = ConfusionMatrixDisplay(cm,display_labels=names)
    disp.plot()
    disp.ax_.tick_params(axis='x', rotation=70)
    plt.savefig(f"data/cm_{size}.png")
    plt.show()
    
    
    cr = classification_report(y_true, y_pred,zero_division=0,output_dict=True)
    print(classification_report(y_true, y_pred,zero_division=0))
    accuracy.append(cr['accuracy'])
    
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(sizes,accuracy,'ro')
plt.ylim(0,1)
plt.xlabel('Image size')
plt.ylabel('Accuracy')
plt.grid()
plt.savefig(f"data/accuracy.png")
plt.show()
# Out:
#                        precision    recall  f1-score   support
#
#         *NOFACEFOUND*       0.00      0.00      0.00         0
#      Alejandro_Toledo       0.43      0.23      0.30        13
#          Ariel_Sharon       0.38      0.21      0.27        14
#           Chris_Evans       0.17      0.10      0.12        10
#       Chris_Hemsworth       0.40      0.25      0.31         8
#      Daniel_Radcliffe       0.50      0.50      0.50        10
#     Denzel_Washington       0.00      0.00      0.00         8
#           Emma_Watson       0.00      0.00      0.00         9
#        Eugenio_Derbez       0.20      0.44      0.28         9
#         George_W_Bush       0.43      0.30      0.35        10
#       Guillermo_Coria       0.62      0.67      0.64        12
#             Hans_Blix       0.60      0.20      0.30        15
#      Jennifer_Aniston       0.25      0.25      0.25        12
#            Kofi_Annan       0.33      0.33      0.33        12
#         Mahmoud_Abbas       0.33      0.25      0.29         8
# Megawati_Sukarnoputri       0.33      0.33      0.33         9
#        Morgan_Freeman       0.60      0.60      0.60        10
#         Ricardo_Lagos       0.33      0.27      0.30        11
#          Roh_Moo-hyun       0.38      0.38      0.38        13
#          Ryan_Gosling       0.11      0.10      0.11        10
#           Salma_Hayek       0.60      0.67      0.63         9
#    Scarlett_Johansson       0.20      0.12      0.15         8
#       Serena_Williams       0.43      0.30      0.35        10
#               Unknown       0.00      0.00      0.00         0
#           Uzmar_Gomez       0.14      1.00      0.25         2
#            Will_Smith       0.12      0.17      0.14         6
#
#              accuracy                           0.30       238
#             macro avg       0.30      0.30      0.28       238
#          weighted avg       0.35      0.30      0.31       238
#                        precision    recall  f1-score   support
#
#         *NOFACEFOUND*       0.00      0.00      0.00         0
#      Alejandro_Toledo       0.50      0.31      0.38        13
#          Ariel_Sharon       0.33      0.29      0.31        14
#           Chris_Evans       0.00      0.00      0.00        10
#       Chris_Hemsworth       0.33      0.25      0.29         8
#      Daniel_Radcliffe       0.71      0.50      0.59        10
#     Denzel_Washington       0.00      0.00      0.00         8
#           Emma_Watson       0.00      0.00      0.00         9
#        Eugenio_Derbez       0.25      0.44      0.32         9
#         George_W_Bush       0.50      0.20      0.29        10
#       Guillermo_Coria       0.67      0.67      0.67        12
#             Hans_Blix       0.67      0.40      0.50        15
#      Jennifer_Aniston       0.50      0.50      0.50        12
#            Kofi_Annan       0.42      0.42      0.42        12
#         Mahmoud_Abbas       0.20      0.25      0.22         8
# Megawati_Sukarnoputri       0.50      0.56      0.53         9
#        Morgan_Freeman       0.60      0.60      0.60        10
#         Ricardo_Lagos       0.23      0.27      0.25        11
#          Roh_Moo-hyun       0.44      0.54      0.48        13
#          Ryan_Gosling       0.21      0.30      0.25        10
#           Salma_Hayek       0.73      0.89      0.80         9
#    Scarlett_Johansson       1.00      0.12      0.22         8
#       Serena_Williams       0.86      0.60      0.71        10
#               Unknown       0.00      0.00      0.00         0
#           Uzmar_Gomez       0.20      1.00      0.33         2
#            Will_Smith       0.25      0.17      0.20         6
#
#              accuracy                           0.38       238
#             macro avg       0.39      0.36      0.34       238
#          weighted avg       0.44      0.38      0.38       238
#                        precision    recall  f1-score   support
#
#         *NOFACEFOUND*       0.00      0.00      0.00         0
#      Alejandro_Toledo       0.00      0.00      0.00        13
#          Ariel_Sharon       0.56      0.36      0.43        14
#           Chris_Evans       0.23      0.30      0.26        10
#       Chris_Hemsworth       0.20      0.12      0.15         8
#      Daniel_Radcliffe       0.67      0.40      0.50        10
#     Denzel_Washington       0.00      0.00      0.00         8
#           Emma_Watson       0.50      0.11      0.18         9
#        Eugenio_Derbez       0.30      0.67      0.41         9
#         George_W_Bush       0.43      0.30      0.35        10
#       Guillermo_Coria       0.82      0.75      0.78        12
#             Hans_Blix       0.67      0.53      0.59        15
#      Jennifer_Aniston       0.50      0.50      0.50        12
#            Kofi_Annan       0.43      0.50      0.46        12
#         Mahmoud_Abbas       0.33      0.38      0.35         8
# Megawati_Sukarnoputri       0.67      0.89      0.76         9
#        Morgan_Freeman       0.45      0.50      0.48        10
#         Ricardo_Lagos       0.29      0.36      0.32        11
#          Roh_Moo-hyun       0.50      0.69      0.58        13
#          Ryan_Gosling       0.17      0.10      0.12        10
#           Salma_Hayek       0.64      0.78      0.70         9
#    Scarlett_Johansson       0.33      0.12      0.18         8
#       Serena_Williams       0.75      0.60      0.67        10
#               Unknown       0.00      0.00      0.00         0
#           Uzmar_Gomez       0.33      1.00      0.50         2
#            Will_Smith       0.00      0.00      0.00         6
#
#              accuracy                           0.41       238
#             macro avg       0.38      0.38      0.36       238
#          weighted avg       0.43      0.41      0.40       238
#                        precision    recall  f1-score   support
#
#         *NOFACEFOUND*       0.00      0.00      0.00         0
#      Alejandro_Toledo       0.50      0.15      0.24        13
#          Ariel_Sharon       0.27      0.21      0.24        14
#           Chris_Evans       0.33      0.30      0.32        10
#       Chris_Hemsworth       0.25      0.12      0.17         8
#      Daniel_Radcliffe       0.86      0.60      0.71        10
#     Denzel_Washington       0.00      0.00      0.00         8
#           Emma_Watson       0.40      0.22      0.29         9
#        Eugenio_Derbez       0.24      0.44      0.31         9
#         George_W_Bush       0.40      0.20      0.27        10
#       Guillermo_Coria       0.83      0.83      0.83        12
#             Hans_Blix       0.89      0.53      0.67        15
#      Jennifer_Aniston       0.57      0.33      0.42        12
#            Kofi_Annan       0.36      0.33      0.35        12
#         Mahmoud_Abbas       0.27      0.50      0.35         8
# Megawati_Sukarnoputri       0.60      1.00      0.75         9
#        Morgan_Freeman       0.55      0.60      0.57        10
#         Ricardo_Lagos       0.35      0.55      0.43        11
#          Roh_Moo-hyun       0.56      0.69      0.62        13
#          Ryan_Gosling       0.22      0.20      0.21        10
#           Salma_Hayek       0.62      0.89      0.73         9
#    Scarlett_Johansson       0.25      0.12      0.17         8
#       Serena_Williams       0.83      0.50      0.62        10
#               Unknown       0.00      0.00      0.00         0
#           Uzmar_Gomez       0.20      1.00      0.33         2
#            Will_Smith       0.00      0.00      0.00         6
#
#              accuracy                           0.42       238
#             macro avg       0.40      0.40      0.37       238
#          weighted avg       0.47      0.42      0.42       238
#                        precision    recall  f1-score   support
#
#         *NOFACEFOUND*       0.00      0.00      0.00         0
#      Alejandro_Toledo       0.33      0.08      0.12        13
#          Ariel_Sharon       0.60      0.43      0.50        14
#           Chris_Evans       0.43      0.30      0.35        10
#       Chris_Hemsworth       0.50      0.25      0.33         8
#      Daniel_Radcliffe       0.50      0.50      0.50        10
#     Denzel_Washington       0.33      0.12      0.18         8
#           Emma_Watson       0.50      0.22      0.31         9
#        Eugenio_Derbez       0.45      0.56      0.50         9
#         George_W_Bush       0.38      0.30      0.33        10
#       Guillermo_Coria       0.64      0.75      0.69        12
#             Hans_Blix       0.89      0.53      0.67        15
#      Jennifer_Aniston       0.55      0.50      0.52        12
#            Kofi_Annan       0.33      0.33      0.33        12
#         Mahmoud_Abbas       0.30      0.38      0.33         8
# Megawati_Sukarnoputri       0.78      0.78      0.78         9
#        Morgan_Freeman       0.56      0.50      0.53        10
#         Ricardo_Lagos       0.25      0.36      0.30        11
#          Roh_Moo-hyun       0.58      0.85      0.69        13
#          Ryan_Gosling       0.29      0.20      0.24        10
#           Salma_Hayek       0.67      0.89      0.76         9
#    Scarlett_Johansson       0.50      0.12      0.20         8
#       Serena_Williams       0.71      0.50      0.59        10
#               Unknown       0.00      0.00      0.00         0
#           Uzmar_Gomez       0.33      1.00      0.50         2
#            Will_Smith       0.00      0.00      0.00         6
#
#              accuracy                           0.43       238
#             macro avg       0.44      0.40      0.39       238
#          weighted avg       0.50      0.43      0.44       238
#                        precision    recall  f1-score   support
#
#         *NOFACEFOUND*       0.00      0.00      0.00         0
#      Alejandro_Toledo       0.67      0.15      0.25        13
#          Ariel_Sharon       0.50      0.21      0.30        14
#           Chris_Evans       0.38      0.30      0.33        10
#       Chris_Hemsworth       0.50      0.38      0.43         8
#      Daniel_Radcliffe       0.62      0.50      0.56        10
#     Denzel_Washington       0.25      0.25      0.25         8
#           Emma_Watson       0.67      0.22      0.33         9
#        Eugenio_Derbez       0.56      0.56      0.56         9
#         George_W_Bush       0.36      0.40      0.38        10
#       Guillermo_Coria       0.64      0.58      0.61        12
#             Hans_Blix       0.70      0.47      0.56        15
#      Jennifer_Aniston       0.78      0.58      0.67        12
#            Kofi_Annan       0.60      0.25      0.35        12
#         Mahmoud_Abbas       0.27      0.38      0.32         8
# Megawati_Sukarnoputri       0.78      0.78      0.78         9
#        Morgan_Freeman       0.86      0.60      0.71        10
#         Ricardo_Lagos       0.44      0.36      0.40        11
#          Roh_Moo-hyun       0.58      0.85      0.69        13
#          Ryan_Gosling       0.60      0.30      0.40        10
#           Salma_Hayek       0.64      0.78      0.70         9
#    Scarlett_Johansson       0.40      0.25      0.31         8
#       Serena_Williams       0.75      0.60      0.67        10
#               Unknown       0.00      0.00      0.00         0
#           Uzmar_Gomez       0.22      1.00      0.36         2
#            Will_Smith       0.00      0.00      0.00         6
#
#              accuracy                           0.44       238
#             macro avg       0.49      0.41      0.42       238
#          weighted avg       0.56      0.44      0.47       238
